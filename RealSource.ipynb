# %%
import os
from __future__ import print_function, division
import pandas as pd
from datetime import timedelta
from time import strftime
import numpy as np

path = '/home/nilm/Desktop/III_NILM/data' # multi_group
os.chdir(path)

# %%
"""
    prepare training data from 'multi_group', which can be downloaded from google drive
    collection : data_in_dictionary, training data
    train_builing : IdList, the building for training
    bprob = IdProbility, the probabilities for the training builings. 
    activation_prob = ActivationProbility, the probabilities for the activations
    
"""
# Out:
# "\n    prepare training data from 'multi_group', which can be downloaded from google drive\n    collection : data_in_dictionary, training data\n    train_builing : IdList, the building for training\n    bprob = IdProbility, the probabilities for the training builings. \n    activation_prob = ActivationProbility, the probabilities for the activations\n    \n"

# %%
train_builing = [14, 19, 28, 39]
bprob = []
collection = {} # training data
activation_prob = {} #  ActivationProbility

# %%
# prepare the related config
for item in sorted(train_builing):
    pathfile = os.path.join(path,'multi_group',str(item))
    aprob = []
    ActivationsList = os.listdir(pathfile)
    ActivationCollection = {}

    for activation in ActivationsList:
        activation_data = pd.read_csv(pathfile+'/'+activation, index_col=0)
        #print(len(activation_data))
        aprob.append(len(activation_data))
        ActivationCollection[str(activation[:-15])]=activation_data
    bprob.append(sum(aprob))
    collection['id_'+str(item)] =  ActivationCollection
    activation_prob['id_'+ str(item)] = [i/sum(aprob) for i in aprob]
building_prob = [i/sum(bprob) for i in bprob]

# %%
class Sequence(object):
    """
    Attributes
    ----------
    input : np.ndarray
    target : np.ndarray
    all_appliances : pd.DataFrame
        Column names are the appliance names.
    metadata : dict
    weights : np.ndarray or None
    """
    def __init__(self, shape, target_channels_in_list):
        self.input = np.zeros(shape, dtype=np.float32)
        self.target = {}
        for target_channel in target_channels_in_list:
            self.target[str(target_channel)] = np.zeros(shape, dtype=np.float32)

# %%
# the RealSource, which will replace the original one
class RealSource(object):
    
    def __init__(self, data_in_dictionary, target_channels_in_list, seq_length, IdList, IdProbility, ActivationProbility,
                num_seq_per_batch=32):
        self.data_in_dictionary = data_in_dictionary
        self.target_channels_in_list = target_channels_in_list
        self.seq_length = seq_length
        self.IdList = IdList
        self.IdProbility = IdProbility
        self.ActivationProbility = ActivationProbility
        self.num_seq_per_batch = num_seq_per_batch
    
    def _select_building(self, IdList, IdProbility):
        """
        For Example:
        
        _select_building(train_builing, building_prob), where
        train_builing = [1, 14, 19]
        building_prob = [0.5, 0.2, 0.3]
        """
        return np.random.choice(IdList, 1, p=IdProbility)
    
    def _select_activation(self, ActivationList, ActivationProbility):
        """
        For Example:
        
        _select_activation(range(len(activation_prob['id_1'])), activation_prob['id_1']), where
        range(len(activation_prob['id_1'])) = [0,1,2,3,5]
        activation_prob['id_1'] = [0.1, 0.1, 0.3, 0.2, 0.3]
        """
        return np.random.choice(ActivationList, 1, p=ActivationProbility)
    
    def get_seq_and_check(self, data, IdList, IdProbility, ActivationProbility):
        """
        get a batch of data
        For Example:
        get_seq_and_check(collection, train_builing, building_prob, activation_prob)
        collection = data
        train_builing = [1, 14, 19]
        building_prob = [0.5, 0.2, 0.3]
        activation_prob = {'id_1':[0.1, 0.1, 0.3, 0.2, 0.3], 
                            'id_14':[0.1, 0.1, 0.3, 0.2, 0.3],
                            'id_19':[0.1, 0.1, 0.3, 0.2, 0.3]}
        
        Warning:
        ------------------------------------------------------------------------
            Currently, setting max_iter == 120, the gap within select_start and end is self.seq_length*2 points
            If the gap is self.seq_length points, it will not success. The cause needs to be figured out
            In the prototype stage, using main as target
        """
        success_for_enough_data = False
        max_iter_for_enough_data = 0
        while not success_for_enough_data:
            max_iter_for_enough_data +=1
            select_building = self._select_building(IdList, IdProbility)[0]
            select_building = 'id_'+str(select_building)
            activation_prob_for_the_select_building = ActivationProbility[select_building ]
            select_activation = self._select_activation(range(len(activation_prob_for_the_select_building)), 
                                           activation_prob_for_the_select_building)[0]      
            get_seq_before_check = data[select_building][str(select_activation)]
            # double check that the index is datetime format
            get_seq_before_check.index = pd.to_datetime(get_seq_before_check.index)
            if len(get_seq_before_check)>=self.seq_length or  max_iter_for_enough_data >= 32 :
                 success_for_enough_data = True
      
        success = False
        max_iter = 0
        while not success:
            max_iter +=1
            select_start = get_seq_before_check.sample(n=1).index[0]
            end = select_start + timedelta(seconds = 60*self.seq_length*2) 
            if len(get_seq_before_check[select_start:end])>=self.seq_length or max_iter==120:
                success = True
                get_seq_after_check = get_seq_before_check[select_start:end]
        
        if max_iter==120:
            seq = None

        else:
            del get_seq_before_check
            #seq = Sequence(self.seq_length)
            seq = Sequence(self.seq_length, self.target_channels_in_list)
            seq.input = np.array(get_seq_after_check[self.target_channels_in_list[0]].values[:self.seq_length])
            #for target in self.target_channels_in_list[1:]:
            #    seq.target = np.array(get_seq_after_check[target].values[:self.seq_length])
            for target in self.target_channels_in_list[1:]:
                seq.target[str(target)] = np.array(get_seq_after_check[target].values[:self.seq_length])
        return seq
    
    def _get_sequence(self):
        seq=self.get_seq_and_check(data = self.data_in_dictionary, 
                                   IdList = self.IdList, 
                                   IdProbility = self.IdProbility, 
                                   ActivationProbility = self.ActivationProbility)
        return seq
    
    def get_batch(self):
        """
        Returns
        -------
        A Batch object or None if source iterator has hit a StopIteration.
        """

        input_sequences = []
        target_sequences = {}
        none_happened = False
        for target in self.target_channels_in_list[1:]:
                target_sequences[str(target)] = []

        for i in range(self.num_seq_per_batch):
            seq = self._get_sequence()
            
            if seq is None:
                none_happened = True
            else:
                input_sequences.append(seq.input.reshape(self.seq_length,1))
                #target_sequences.append(seq.target.reshape(self.seq_length,1))
                for target in self.target_channels_in_list[1:]:
                    target_sequences[str(target)].append(seq.target[str(target)].reshape(self.seq_length,1))
                
        if not none_happened:
            input_sequences = np.asarray(input_sequences).reshape(self.num_seq_per_batch,self.seq_length,1)
            #target_sequences = np.asarray(target_sequences).reshape(self.num_seq_per_batch,self.seq_length,1)
            for target in self.target_channels_in_list[1:]:
                target_sequences[str(target)] = np.asarray(target_sequences[str(target)]).reshape(self.num_seq_per_batch,self.seq_length,1)
        else:
            input_sequences = None
            target_sequences = None
            
        return input_sequences, target_sequences

# %%
from keras.models import Sequential, Model
from keras.layers import Input, Dense, Activation, Reshape, Flatten, Conv1D, MaxPooling1D, Dropout, LSTM, TimeDistributed, Bidirectional
from keras.optimizers import RMSprop


MODEL_CONV_FILTERS = 32
MODEL_CONV_KERNEL_SIZE = 18
MODEL_CONV_STRIDES = 1
MODEL_CONV_PADDING = 'same'



seq_length = 60

# conv
x = Input(shape=(60,1))
conv_1 = Conv1D(filters=MODEL_CONV_FILTERS, kernel_size=MODEL_CONV_KERNEL_SIZE, padding=MODEL_CONV_PADDING, activation='relu')(x)
drop_1 = Dropout(0.12)(conv_1)

conv_2 = Conv1D(filters=64, kernel_size=12, padding=MODEL_CONV_PADDING, activation='relu')(drop_1)
drop_2 = Dropout(0.14)(conv_2)

conv_3 = Conv1D(filters=128, kernel_size=7, padding=MODEL_CONV_PADDING, activation='relu')(drop_2)
pool_3 = MaxPooling1D(pool_size=2)(conv_3)
drop_3 = Dropout(0.18)(pool_3)

conv_4 = Conv1D(filters=128, kernel_size=3, padding=MODEL_CONV_PADDING, activation='relu')(drop_3)
pool_4 = MaxPooling1D(pool_size=2)(conv_4)
drop_4 = Dropout(0.2)(pool_4)

# reshape
flat_4 = Flatten()(drop_4)

dense_5 = Dense(1280, activation='relu')(flat_4)
drop_5 = Dropout(0.16)(dense_5)

dense_6 = Dense(960, activation='relu')(drop_5)
drop_6 = Dropout(0.14)(dense_6)

dense_7 = Dense(720, activation='relu')(drop_6)
drop_7 = Dropout(0.12)(dense_7)

reshape_8 = Reshape(target_shape=(seq_length, 12))(drop_7)

outputs_disaggregation = []

for appliance_name in ['fridge','air conditioner']:
    biLSTM_1 = Bidirectional(LSTM(6, return_sequences=True))(reshape_8)
    biLSTM_2 = Bidirectional(LSTM(3, return_sequences=True))(biLSTM_1)
    outputs_disaggregation.append(TimeDistributed(Dense(1, activation='relu'), name=appliance_name.replace(" ", "_"))(biLSTM_2))

model = Model(inputs=x, outputs=outputs_disaggregation)
optimizer = RMSprop(lr=0.001, clipnorm=4)
model.compile(optimizer=optimizer, loss='mse', metrics=['mae', 'mse'])

# %%
"""
    target_channel_in_list = ['main','main'] need to be like ['main','fridge','air conditioner']
"""
# Out:
# "\n    target_channel_in_list = ['main','main'] need to be like ['main','fridge','air conditioner']\n"

# %%
real = RealSource(data_in_dictionary = collection, 
                  target_channels_in_list = ['main','fridge','air conditioner'], 
                  seq_length=60, 
                  IdList = train_builing, 
                  IdProbility = building_prob,
                  ActivationProbility = activation_prob)
main, target = real.get_batch()

# %%
for i in range(5000):
    if i % 100 == 0:
        print('Step : {} , Time : {}\n'.format(i,strftime('%Y-%m-%d_%H_%M')))
    main, target = real.get_batch()
    while main is None or target is None:
        main, target = real.get_batch()
    train_metrics = model.train_on_batch(x=main, y=[target['fridge'], target['air conditioner']])
    if i % 100 == 0:
        for i, metrics_name in enumerate(model.metrics_names):
            print('{}={:.4f}, '.format(metrics_name, train_metrics[i]))
            print('')
# Out:
# Step : 0 , Time : 2018-06-21_23_07
#
# loss=5754.4341,
#
# fridge_loss=5654.8901,
#
# air_conditioner_loss=99.5440,
#
# fridge_mean_absolute_error=42.8420,
#
# fridge_mean_squared_error=5654.8901,
#
# air_conditioner_mean_absolute_error=6.8266,
#
# air_conditioner_mean_squared_error=99.5440,
#
# Step : 100 , Time : 2018-06-21_23_08
#
# loss=5294.1201,
#
# fridge_loss=5222.7607,
#
# air_conditioner_loss=71.3592,
#
# fridge_mean_absolute_error=41.6634,
#
# fridge_mean_squared_error=5222.7612,
#
# air_conditioner_mean_absolute_error=7.0252,
#
# air_conditioner_mean_squared_error=71.3592,
#
# Step : 200 , Time : 2018-06-21_23_09
#
# loss=9257.2090,
#
# fridge_loss=5418.9023,
#
# air_conditioner_loss=3838.3064,
#
# fridge_mean_absolute_error=45.9283,
#
# fridge_mean_squared_error=5418.9033,
#
# air_conditioner_mean_absolute_error=14.1532,
#
# air_conditioner_mean_squared_error=3838.3047,
#
# Step : 300 , Time : 2018-06-21_23_09
#
# loss=6208.2095,
#
# fridge_loss=6165.5967,
#
# air_conditioner_loss=42.6127,
#
# fridge_mean_absolute_error=46.8950,
#
# fridge_mean_squared_error=6165.5864,
#
# air_conditioner_mean_absolute_error=5.6023,
#
# air_conditioner_mean_squared_error=42.6127,
#
# Step : 400 , Time : 2018-06-21_23_10
#
# loss=4471.5518,
#
# fridge_loss=4417.6387,
#
# air_conditioner_loss=53.9131,
#
# fridge_mean_absolute_error=40.4344,
#
# fridge_mean_squared_error=4417.6431,
#
# air_conditioner_mean_absolute_error=6.3927,
#
# air_conditioner_mean_squared_error=53.9131,
#
# Step : 500 , Time : 2018-06-21_23_11
#
# loss=6677.6870,
#
# fridge_loss=6644.4199,
#
# air_conditioner_loss=33.2670,
#
# fridge_mean_absolute_error=47.2817,
#
# fridge_mean_squared_error=6644.4404,
#
# air_conditioner_mean_absolute_error=5.2252,
#
# air_conditioner_mean_squared_error=33.2669,
#
# Step : 600 , Time : 2018-06-21_23_11
#
# loss=6151.6631,
#
# fridge_loss=6112.8936,
#
# air_conditioner_loss=38.7696,
#
# fridge_mean_absolute_error=44.3472,
#
# fridge_mean_squared_error=6112.8979,
#
# air_conditioner_mean_absolute_error=5.9827,
#
# air_conditioner_mean_squared_error=38.7697,
#
# Step : 700 , Time : 2018-06-21_23_12
#
# loss=5659.6084,
#
# fridge_loss=5624.2051,
#
# air_conditioner_loss=35.4032,
#
# fridge_mean_absolute_error=42.6544,
#
# fridge_mean_squared_error=5624.1924,
#
# air_conditioner_mean_absolute_error=5.3630,
#
# air_conditioner_mean_squared_error=35.4032,
#
# Step : 800 , Time : 2018-06-21_23_12
#
# loss=22585.5273,
#
# fridge_loss=6033.8799,
#
# air_conditioner_loss=16551.6465,
#
# fridge_mean_absolute_error=48.5860,
#
# fridge_mean_squared_error=6033.8774,
#
# air_conditioner_mean_absolute_error=22.0037,
#
# air_conditioner_mean_squared_error=16551.6641,
#
# Step : 900 , Time : 2018-06-21_23_13
#
# loss=8267.1592,
#
# fridge_loss=8234.9062,
#
# air_conditioner_loss=32.2528,
#
# fridge_mean_absolute_error=58.0161,
#
# fridge_mean_squared_error=8234.9170,
#
# air_conditioner_mean_absolute_error=4.7177,
#
# air_conditioner_mean_squared_error=32.2528,
#
# Step : 1000 , Time : 2018-06-21_23_14
#
# loss=7312.4443,
#
# fridge_loss=7280.1006,
#
# air_conditioner_loss=32.3437,
#
# fridge_mean_absolute_error=52.4676,
#
# fridge_mean_squared_error=7280.0962,
#
# air_conditioner_mean_absolute_error=5.1081,
#
# air_conditioner_mean_squared_error=32.3437,
#
# Step : 1100 , Time : 2018-06-21_23_14
#
# loss=6152.9312,
#
# fridge_loss=6116.8281,
#
# air_conditioner_loss=36.1032,
#
# fridge_mean_absolute_error=47.5687,
#
# fridge_mean_squared_error=6116.8262,
#
# air_conditioner_mean_absolute_error=5.1893,
#
# air_conditioner_mean_squared_error=36.1032,
#
# Step : 1200 , Time : 2018-06-21_23_15
#
# loss=5490.0254,
#
# fridge_loss=5454.4219,
#
# air_conditioner_loss=35.6035,
#
# fridge_mean_absolute_error=46.1335,
#
# fridge_mean_squared_error=5454.4263,
#
# air_conditioner_mean_absolute_error=5.0691,
#
# air_conditioner_mean_squared_error=35.6035,
#
# Step : 1300 , Time : 2018-06-21_23_16
#
# loss=10232.7314,
#
# fridge_loss=9010.8965,
#
# air_conditioner_loss=1221.8347,
#
# fridge_mean_absolute_error=57.7224,
#
# fridge_mean_squared_error=9010.9189,
#
# air_conditioner_mean_absolute_error=8.4192,
#
# air_conditioner_mean_squared_error=1221.8354,
#
# Step : 1400 , Time : 2018-06-21_23_16
#
# loss=62101.9531,
#
# fridge_loss=8485.1865,
#
# air_conditioner_loss=53616.7656,
#
# fridge_mean_absolute_error=58.8925,
#
# fridge_mean_squared_error=8485.1836,
#
# air_conditioner_mean_absolute_error=36.1532,
#
# air_conditioner_mean_squared_error=53616.7539,
#
# Step : 1500 , Time : 2018-06-21_23_17
#
# loss=5918.8906,
#
# fridge_loss=5872.6055,
#
# air_conditioner_loss=46.2852,
#
# fridge_mean_absolute_error=49.9809,
#
# fridge_mean_squared_error=5872.6079,
#
# air_conditioner_mean_absolute_error=5.8014,
#
# air_conditioner_mean_squared_error=46.2852,
#
# Step : 1600 , Time : 2018-06-21_23_17
#
# loss=6437.7803,
#
# fridge_loss=6404.7231,
#
# air_conditioner_loss=33.0569,
#
# fridge_mean_absolute_error=48.7852,
#
# fridge_mean_squared_error=6404.7168,
#
# air_conditioner_mean_absolute_error=5.1103,
#
# air_conditioner_mean_squared_error=33.0569,
#
# Step : 1700 , Time : 2018-06-21_23_18
#
# loss=6290.6646,
#
# fridge_loss=6257.1826,
#
# air_conditioner_loss=33.4820,
#
# fridge_mean_absolute_error=50.8029,
#
# fridge_mean_squared_error=6257.1865,
#
# air_conditioner_mean_absolute_error=4.9687,
#
# air_conditioner_mean_squared_error=33.4820,
#
# Step : 1800 , Time : 2018-06-21_23_19
#
# loss=4938.5054,
#
# fridge_loss=4872.9990,
#
# air_conditioner_loss=65.5065,
#
# fridge_mean_absolute_error=43.1175,
#
# fridge_mean_squared_error=4872.9980,
#
# air_conditioner_mean_absolute_error=5.7088,
#
# air_conditioner_mean_squared_error=65.5065,
#
# Step : 1900 , Time : 2018-06-21_23_19
#
# loss=5638.8223,
#
# fridge_loss=3918.0044,
#
# air_conditioner_loss=1720.8179,
#
# fridge_mean_absolute_error=38.1696,
#
# fridge_mean_squared_error=3917.9990,
#
# air_conditioner_mean_absolute_error=10.8954,
#
# air_conditioner_mean_squared_error=1720.8192,
#
# Step : 2000 , Time : 2018-06-21_23_20
#
# loss=7743.1514,
#
# fridge_loss=6055.6592,
#
# air_conditioner_loss=1687.4921,
#
# fridge_mean_absolute_error=43.4510,
#
# fridge_mean_squared_error=6055.6465,
#
# air_conditioner_mean_absolute_error=10.9031,
#
# air_conditioner_mean_squared_error=1687.4915,
#
# Step : 2100 , Time : 2018-06-21_23_21
#
# loss=6932.8081,
#
# fridge_loss=6903.5820,
#
# air_conditioner_loss=29.2258,
#
# fridge_mean_absolute_error=47.0899,
#
# fridge_mean_squared_error=6903.5835,
#
# air_conditioner_mean_absolute_error=4.6541,
#
# air_conditioner_mean_squared_error=29.2258,
#
# Step : 2200 , Time : 2018-06-21_23_21
#
# loss=6967.0732,
#
# fridge_loss=6908.1128,
#
# air_conditioner_loss=58.9607,
#
# fridge_mean_absolute_error=55.4012,
#
# fridge_mean_squared_error=6908.1147,
#
# air_conditioner_mean_absolute_error=5.7658,
#
# air_conditioner_mean_squared_error=58.9607,
#
# Step : 2300 , Time : 2018-06-21_23_22
#
# loss=6316.7603,
#
# fridge_loss=6271.8174,
#
# air_conditioner_loss=44.9430,
#
# fridge_mean_absolute_error=50.7104,
#
# fridge_mean_squared_error=6271.8252,
#
# air_conditioner_mean_absolute_error=5.8600,
#
# air_conditioner_mean_squared_error=44.9430,
#
# Step : 2400 , Time : 2018-06-21_23_23
#
# loss=6325.5044,
#
# fridge_loss=5787.0234,
#
# air_conditioner_loss=538.4811,
#
# fridge_mean_absolute_error=46.7531,
#
# fridge_mean_squared_error=5787.0186,
#
# air_conditioner_mean_absolute_error=6.7607,
#
# air_conditioner_mean_squared_error=538.4814,
#
# Step : 2500 , Time : 2018-06-21_23_24
#
# loss=5511.6284,
#
# fridge_loss=5474.1006,
#
# air_conditioner_loss=37.5280,
#
# fridge_mean_absolute_error=49.8702,
#
# fridge_mean_squared_error=5474.1050,
#
# air_conditioner_mean_absolute_error=4.8691,
#
# air_conditioner_mean_squared_error=37.5279,
#
# Step : 2600 , Time : 2018-06-21_23_24
#
# loss=11847.0430,
#
# fridge_loss=11806.9531,
#
# air_conditioner_loss=40.0900,
#
# fridge_mean_absolute_error=54.4560,
#
# fridge_mean_squared_error=11806.9600,
#
# air_conditioner_mean_absolute_error=5.5367,
#
# air_conditioner_mean_squared_error=40.0901,
#
# Step : 2700 , Time : 2018-06-21_23_25
#
# loss=8604.0000,
#
# fridge_loss=8570.0859,
#
# air_conditioner_loss=33.9138,
#
# fridge_mean_absolute_error=64.0919,
#
# fridge_mean_squared_error=8570.0996,
#
# air_conditioner_mean_absolute_error=4.6381,
#
# air_conditioner_mean_squared_error=33.9138,
#
# Step : 2800 , Time : 2018-06-21_23_26
#
# loss=5319.1030,
#
# fridge_loss=5278.1289,
#
# air_conditioner_loss=40.9743,
#
# fridge_mean_absolute_error=50.6001,
#
# fridge_mean_squared_error=5278.1377,
#
# air_conditioner_mean_absolute_error=4.9618,
#
# air_conditioner_mean_squared_error=40.9743,
# Step : 2900 , Time : 2018-06-21_23_27
#
# loss=3882.2036,
#
# fridge_loss=3833.1074,
#
# air_conditioner_loss=49.0962,
#
# fridge_mean_absolute_error=40.8137,
#
# fridge_mean_squared_error=3833.1055,
#
# air_conditioner_mean_absolute_error=5.9585,
#
# air_conditioner_mean_squared_error=49.0963,
#
# Step : 3000 , Time : 2018-06-21_23_27
#
# loss=4043.9434,
#
# fridge_loss=4004.0449,
#
# air_conditioner_loss=39.8985,
#
# fridge_mean_absolute_error=41.8536,
#
# fridge_mean_squared_error=4004.0496,
#
# air_conditioner_mean_absolute_error=4.9355,
#
# air_conditioner_mean_squared_error=39.8985,
#
# Step : 3100 , Time : 2018-06-21_23_28
#
# loss=4727.2544,
#
# fridge_loss=4678.3252,
#
# air_conditioner_loss=48.9291,
#
# fridge_mean_absolute_error=45.8106,
#
# fridge_mean_squared_error=4678.3169,
#
# air_conditioner_mean_absolute_error=5.6762,
#
# air_conditioner_mean_squared_error=48.9291,
#
# Step : 3200 , Time : 2018-06-21_23_29
#
# loss=5956.8047,
#
# fridge_loss=3678.8855,
#
# air_conditioner_loss=2277.9189,
#
# fridge_mean_absolute_error=39.1749,
#
# fridge_mean_squared_error=3678.8884,
#
# air_conditioner_mean_absolute_error=12.8945,
#
# air_conditioner_mean_squared_error=2277.9187,
#
# Step : 3300 , Time : 2018-06-21_23_29
#
# loss=38285.9844,
#
# fridge_loss=6444.3911,
#
# air_conditioner_loss=31841.5918,
#
# fridge_mean_absolute_error=53.6972,
#
# fridge_mean_squared_error=6444.4028,
#
# air_conditioner_mean_absolute_error=25.0666,
#
# air_conditioner_mean_squared_error=31841.5879,
#
# Step : 3400 , Time : 2018-06-21_23_30
#
# loss=6529.1240,
#
# fridge_loss=6465.0381,
#
# air_conditioner_loss=64.0858,
#
# fridge_mean_absolute_error=55.7139,
#
# fridge_mean_squared_error=6465.0337,
#
# air_conditioner_mean_absolute_error=6.9692,
#
# air_conditioner_mean_squared_error=64.0858,
#
# Step : 3500 , Time : 2018-06-21_23_30
#
# loss=7852.2227,
#
# fridge_loss=5035.0537,
#
# air_conditioner_loss=2817.1692,
#
# fridge_mean_absolute_error=47.1831,
#
# fridge_mean_squared_error=5035.0532,
#
# air_conditioner_mean_absolute_error=14.8258,
#
# air_conditioner_mean_squared_error=2817.1687,
#
# Step : 3600 , Time : 2018-06-21_23_31
#
# loss=6196.0410,
#
# fridge_loss=6148.4839,
#
# air_conditioner_loss=47.5571,
#
# fridge_mean_absolute_error=50.6511,
#
# fridge_mean_squared_error=6148.4897,
#
# air_conditioner_mean_absolute_error=6.2585,
#
# air_conditioner_mean_squared_error=47.5571,
#
# Step : 3700 , Time : 2018-06-21_23_32
#
# loss=7771.0693,
#
# fridge_loss=5587.6367,
#
# air_conditioner_loss=2183.4324,
#
# fridge_mean_absolute_error=45.3635,
#
# fridge_mean_squared_error=5587.6284,
#
# air_conditioner_mean_absolute_error=13.3326,
#
# air_conditioner_mean_squared_error=2183.4324,
#
# Step : 3800 , Time : 2018-06-21_23_32
#
# loss=4379.6240,
#
# fridge_loss=4320.6665,
#
# air_conditioner_loss=58.9577,
#
# fridge_mean_absolute_error=47.8107,
#
# fridge_mean_squared_error=4320.6670,
#
# air_conditioner_mean_absolute_error=6.8835,
#
# air_conditioner_mean_squared_error=58.9577,
#
# Step : 3900 , Time : 2018-06-21_23_33
#
# loss=4935.4141,
#
# fridge_loss=4890.2104,
#
# air_conditioner_loss=45.2037,
#
# fridge_mean_absolute_error=50.4129,
#
# fridge_mean_squared_error=4890.2104,
#
# air_conditioner_mean_absolute_error=6.0037,
#
# air_conditioner_mean_squared_error=45.2037,
#
# Step : 4000 , Time : 2018-06-21_23_34
#
# loss=4572.7461,
#
# fridge_loss=4523.8848,
#
# air_conditioner_loss=48.8613,
#
# fridge_mean_absolute_error=47.1801,
#
# fridge_mean_squared_error=4523.8843,
#
# air_conditioner_mean_absolute_error=6.2127,
#
# air_conditioner_mean_squared_error=48.8613,
#
# Step : 4100 , Time : 2018-06-21_23_35
#
# loss=9271.1289,
#
# fridge_loss=4091.0769,
#
# air_conditioner_loss=5180.0518,
#
# fridge_mean_absolute_error=43.8393,
#
# fridge_mean_squared_error=4091.0818,
#
# air_conditioner_mean_absolute_error=8.3971,
#
# air_conditioner_mean_squared_error=5180.0518,
#
# Step : 4200 , Time : 2018-06-21_23_35
#
# loss=3247.3621,
#
# fridge_loss=3187.7053,
#
# air_conditioner_loss=59.6568,
#
# fridge_mean_absolute_error=41.7584,
#
# fridge_mean_squared_error=3187.7041,
#
# air_conditioner_mean_absolute_error=6.5117,
#
# air_conditioner_mean_squared_error=59.6568,
#
# Step : 4300 , Time : 2018-06-21_23_36
#
# loss=4852.1372,
#
# fridge_loss=4807.3438,
#
# air_conditioner_loss=44.7935,
#
# fridge_mean_absolute_error=47.0941,
#
# fridge_mean_squared_error=4807.3423,
#
# air_conditioner_mean_absolute_error=5.9208,
#
# air_conditioner_mean_squared_error=44.7935,
#
# Step : 4400 , Time : 2018-06-21_23_37
#
# loss=4728.7856,
#
# fridge_loss=4679.2070,
#
# air_conditioner_loss=49.5784,
#
# fridge_mean_absolute_error=50.2955,
#
# fridge_mean_squared_error=4679.2056,
#
# air_conditioner_mean_absolute_error=6.2791,
#
# air_conditioner_mean_squared_error=49.5784,
#
# Step : 4500 , Time : 2018-06-21_23_38
#
# loss=10551.5000,
#
# fridge_loss=7015.2588,
#
# air_conditioner_loss=3536.2417,
#
# fridge_mean_absolute_error=63.5500,
#
# fridge_mean_squared_error=7015.2681,
#
# air_conditioner_mean_absolute_error=10.4388,
#
# air_conditioner_mean_squared_error=3536.2407,
#
# Step : 4600 , Time : 2018-06-21_23_38
#
# loss=5393.6455,
#
# fridge_loss=5356.2607,
#
# air_conditioner_loss=37.3848,
#
# fridge_mean_absolute_error=47.4474,
#
# fridge_mean_squared_error=5356.2515,
#
# air_conditioner_mean_absolute_error=5.5053,
#
# air_conditioner_mean_squared_error=37.3848,
#
# Step : 4700 , Time : 2018-06-21_23_39
#
# loss=7094.1074,
#
# fridge_loss=4732.6572,
#
# air_conditioner_loss=2361.4504,
#
# fridge_mean_absolute_error=49.2510,
#
# fridge_mean_squared_error=4732.6572,
#
# air_conditioner_mean_absolute_error=14.8062,
#
# air_conditioner_mean_squared_error=2361.4495,
#
# Step : 4800 , Time : 2018-06-21_23_40
#
# loss=4063.6675,
#
# fridge_loss=4022.6077,
#
# air_conditioner_loss=41.0597,
#
# fridge_mean_absolute_error=45.8648,
#
# fridge_mean_squared_error=4022.6104,
#
# air_conditioner_mean_absolute_error=5.2154,
#
# air_conditioner_mean_squared_error=41.0597,
#
# Step : 4900 , Time : 2018-06-21_23_40
#
# loss=4764.2788,
#
# fridge_loss=4713.4980,
#
# air_conditioner_loss=50.7808,
#
# fridge_mean_absolute_error=50.9150,
#
# fridge_mean_squared_error=4713.5010,
#
# air_conditioner_mean_absolute_error=6.3976,
#
# air_conditioner_mean_squared_error=50.7808,

# %%
model.save('multi_group__frige_ac.h5')
